# %%
import pandas as pd

# %%
df_preterite = pd.read_csv("preterite.csv")
df_present = pd.read_csv("present.csv")
df_present_continuous = pd.read_csv("present_continuous.csv")
df_future = pd.read_csv("future.csv")
df_traducion = pd.read_csv("traduccion.csv")

# %%
df_present
# Out:
#   Unnamed: 0   be  have   know   see   want    do   take   use   provide  ...  \
# 0          I   am  have   know   see   want    do   take   use   provide  ...
# 1        you  are  have   know   see   want    do   take   use   provide  ...
# 2  he/she/it   is   has  knows  sees  wants  does  takes  uses  provides  ...
# 3         we  are  have   know   see   want    do   take   use   provide  ...
# 4        you  are  have   know   see   want    do   take   use   provide  ...
# 5       they  are  have   know   see   want    do   take   use   provide  ...
#
#      dry   transmit   remind    fix    focus   deal   preserve   break  \
# 0    dry   transmit   remind    fix    focus   deal   preserve   break
# 1    dry   transmit   remind    fix    focus   deal   preserve   break
# 2  dries  transmits  reminds  fixes  focuses  deals  preserves  breaks
# 3    dry   transmit   remind    fix    focus   deal   preserve   break
# 4    dry   transmit   remind    fix    focus   deal   preserve   break
# 5    dry   transmit   remind    fix    focus   deal   preserve   break
#
#     realize    finish
# 0   realize    finish
# 1   realize    finish
# 2  realizes  finishes
# 3   realize    finish
# 4   realize    finish
# 5   realize    finish
#
# [6 rows x 251 columns]
