# %%
import pandas as pd

# %%
df_preterite = pd.read_csv("preterite.csv")
df_present = pd.read_csv("present.csv")
df_present_continuous = pd.read_csv("present_continuous.csv")
df_future = pd.read_csv("future.csv")
df_traduccion = pd.read_csv("traduccion.csv")

# %%
for verbo in df_present_continuous.columns[1:]:
    print(df_present_continuous[verbo][0].split()[1])
# Out:
# being
# having
# knowing
# seeing
# wanting
# doing
# taking
# using
# providing
# making
# going
# getting
# finding
# saying
# telling
# supporting
# needing
# giving
# helping
# including
# coming
# working
# ensuring
# improving
# putting
# talking
# increasing
# asking
# keeping
# allowing
# reducing
# calling
# receiving
# becoming
# liking
# creating
# playing
# believing
# promoting
# protecting
# changing
# living
# leaving
# preventing
# determining
# letting
# meeting
# setting
# understanding
# developing
# loving
# showing
# stopping
# trying
# looking
# considering
# opening
# reading
# remaining
# offering
# staying
# paying
# strengthening
# forming
# starting
# establishing
# sending
# killing
# achieving
# bringing
# hearing
# waiting
# avoiding
# encouraging
# hoping
# adding
# thinking
# following
# controlling
# contributing
# producing
# maintaining
# speaking
# completing
# choosing
# thanking
# obtaining
# buying
# implementing
# listening
# participating
# ...

# %%
for verbos in range(1, len(df_present_continuous.columns)):
    for i in range(len(df_present_continuous)):
        aux, verbo_conjugado = df_present_continuous[f"{df_present_continuous.columns[verbos]}"][i].split(" ")
        print(verbo_conjugado)
# Out:
# being
# being
# being
# being
# being
# being
# having
# having
# having
# having
# having
# having
# knowing
# knowing
# knowing
# knowing
# knowing
# knowing
# seeing
# seeing
# seeing
# seeing
# seeing
# seeing
# wanting
# wanting
# wanting
# wanting
# wanting
# wanting
# doing
# doing
# doing
# doing
# doing
# doing
# taking
# taking
# taking
# taking
# taking
# taking
# using
# using
# using
# using
# using
# using
# providing
# providing
# providing
# providing
# providing
# providing
# making
# making
# making
# making
# making
# making
# going
# going
# going
# going
# going
# going
# getting
# getting
# getting
# getting
# getting
# getting
# finding
# finding
# finding
# finding
# finding
# finding
# saying
# saying
# saying
# saying
# saying
# saying
# telling
# telling
# telling
# telling
# telling
# telling
# supporting
# supporting
# supporting
# supporting
# supporting
# supporting
# needing
# needing
# needing
# needing
# needing
# needing
# giving
# giving
# giving
# ...
